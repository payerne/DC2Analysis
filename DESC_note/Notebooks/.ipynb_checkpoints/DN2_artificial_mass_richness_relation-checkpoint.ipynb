# %%
# %load_ext autoreload

# %autoreload 2
import richness
import GCRCatalogs
import matplotlib.pyplot as plt
import pickle
from astropy.coordinates import SkyCoord, match_coordinates_3d, match_coordinates_sky
import sys
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy.table import Table, QTable, hstack, vstack, join
from astropy import units as u
from astropy.coordinates import SkyCoord, match_coordinates_3d
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
import iminuit
from iminuit import Minuit
cosmo_astropy.critical_density(0.4).to(u.Msun / u.Mpc**3).value
sys.path.append('/pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis')
import corner
import make_profile as prf

sys.path.append('/pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/modeling/')
import miscentering as mis
import two_halo_term as twoh
import mass_conversion as utils
import clmm
import clmm.dataops
from clmm.dataops import compute_tangential_and_cross_components, make_radial_profile, make_bins
from clmm.galaxycluster import GalaxyCluster
import clmm.utils as u
import astropy.units as un
from clmm import Cosmology
from clmm.support import mock_data as mock
import pyccl as ccl
cosmo = Cosmology(H0 = 71.0, Omega_dm0 = 0.265 - 0.0448, Omega_b0 = 0.0448, Omega_k0 = 0.0)
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
cosmo_clmm = Cosmology(H0 = 71.0, Omega_dm0 = 0.265 - 0.0448, Omega_b0 = 0.0448, Omega_k0 = 0.0)
cosmo_ccl  = ccl.Cosmology(Omega_c=0.265-0.0448, Omega_b=0.0448, h=0.71, A_s=2.1e-9, n_s=0.96, Neff=0, Omega_g=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
theta_pivot = [3e14/0.71, 0.6]
theta_mu = [3.19, 0, 0.94]
theta_sigma = [0.33, 0,-0.08]

# %%
def load(filename, **kwargs):

    with open(filename, 'rb') as fin:
        
        return pickle.load(fin, **kwargs)

# %%
dat_SkySim = load('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/Galaxy_Cluster_Catalogs_details/cosmoDC2/SkySim5000_DM_halos.pkl')
profile_SkySim = load('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/p_DC2_validation/SkySim5000/SkySim5000_epsilon_shape_all_bins_ns.pkl')

# %%
dat_SkySim['richness'] = 10**richness.lnLambda(dat_SkySim['redshift'] , np.log10(dat_SkySim['baseDC2/sod_halo_mass']/0.71), theta_mu, theta_sigma, theta_pivot)
# Out:
# /pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
dat_SkySim.colnames
# Out:
# ['dec',
#  'ra',
#  'baseDC2/sod_halo_radius',
#  'halo_id',
#  'halo_mass',
#  'baseDC2/sod_halo_mass',
#  'redshift',
#  'richness']

# %%
plt.hist(np.log10(dat_SkySim['richness']))
# Out:
# (array([4.60000e+01, 1.05500e+03, 1.42440e+04, 7.60170e+04, 1.65898e+05,
#         1.48447e+05, 5.55480e+04, 9.35500e+03, 6.87000e+02, 2.60000e+01]),
#  array([-0.50306028, -0.01377587,  0.47550854,  0.96479295,  1.45407735,
#          1.94336176,  2.43264617,  2.92193058,  3.41121499,  3.9004994 ,
#          4.38978381]),
#  <a list of 10 Patch objects>)

# %%
profile_SkySim.colnames
profile_SkySim['halo_id'] = profile_SkySim['cluster_id']

# %%
profile_SkySim = join(profile_SkySim, dat_SkySim, keys = 'halo_id')

# %%
profile_SkySim.colnames
# Out:
# ['cluster_id',
#  'M200c',
#  'cluster_z',
#  'radial_bin',
#  'gt_av',
#  'gx_av',
#  'radius_av',
#  'norm_sum',
#  'halo_id',
#  'dec',
#  'ra',
#  'baseDC2/sod_halo_radius',
#  'halo_mass',
#  'baseDC2/sod_halo_mass',
#  'redshift',
#  'richness']

# %%
theta_pivot = [3e14/0.71, 0.6]
theta_mu = [3.19, 0, 0.94]
theta_sigma = [0.33, 0,-0.08]

# %%
sum_weights_per_cluster_10 = []
sum_weights_per_cluster_5 = []
for i, cl in enumerate(profile_SkySim):
    mask = (profile_SkySim['radius_av'][i] > 1)*(profile_SkySim['radius_av'][i] < 10)
    sum_weights_per_cluster_10.append(np.sum(profile_SkySim['norm_sum'][i][mask]))
    mask = (profile_SkySim['radius_av'][i] > 1)*(profile_SkySim['radius_av'][i] < 5.5)
    sum_weights_per_cluster_5.append(np.sum(profile_SkySim['norm_sum'][i][mask]))

# %%
profile_SkySim['weight_per_cluster_5'] = np.array(sum_weights_per_cluster_5)*1e27
profile_SkySim['weight_per_cluster_10'] = np.array(sum_weights_per_cluster_10)*1e27

# %%
def binning(corner): return [[corner[i],corner[i+1]] for i in range(len(corner)-1)]
z_corner = np.linspace(0.2, 0.6, 9)
print(z_corner)
#z_corner = [0.2, 0.35, 0.5, 0.65]
Z_bin = binning(z_corner)
#rich_corner = [20,30,45,60, np.inf]
#rich_corner = np.linspace(min(dat_SkySim['richness']), max(dat_SkySim['richness']), 3)
richness = np.array(profile_SkySim['richness'])
#richness = [r[0] for r in richness]
sorte = np.array_split(np.sort(richness), 6)
Richness_bin = [[s[0], s[-1]] for s in sorte]
#rich_corner[-1] = np.inf
#Richness_bin = binning(rich_corner)
Obs_bin = Richness_bin
# Out:
# [0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6 ]

# %%
Richness_bin
# Out:
# [[19.604724496502342, 240.52654945767927],
#  [240.7510704477504, 389.4829127093701],
#  [389.6792433242339, 590.1842096574603],
#  [590.8590949132131, 886.621238674371],
#  [887.1484378531932, 1455.158176622737],
#  [1456.5455894374563, 24534.87257825418]]

# %%
moo = clmm.Modeling(massdef = 'critical', delta_mdef = 200, halo_profile_model = 'nfw')
moo.set_cosmo(cosmo_clmm)
deff = ccl.halos.massdef.MassDef(200, 'critical', c_m_relation=None)
conc = ccl.halos.concentration.ConcentrationDiemer15(mdef=deff)

# %% [markdown]
# ### Mass richness relation

# %%
from statistics import median

# %%
z0 = median(profile_SkySim['cluster_z'])
richness0 = median(profile_SkySim['richness'])
Gamma_5 = 0.75
Gamma_10 = 0.8

# %%
def gaussian(x,mu,sigma):
        return np.exp(-(x-mu)**2/(2*sigma**2))/np.sqrt(2*np.pi*sigma**2)
    
def mu_logM_lambda_f(redshift, logrichness, logM200c0, alpha, beta):
    return logM200c0 + alpha*np.log10((1+redshift)/(1 + z0)) + beta*(logrichness-np.log10(richness0))

# %%
def lnL_binned_1(theta, m200c_mean, m200c_err_mean, logrichness_mean, z_mean):
    logM200c0, alpha, beta = theta
    logm200c_err_mean = m200c_err_mean/(np.log(10)*m200c_mean)
    model = mu_logM_lambda_f(z_mean, logrichness_mean, logM200c0, alpha, beta)
    return np.sum(np.log(gaussian(m200c_mean, 10**model, m200c_err_mean)))

# %%
def lnL_binned_2(theta, m200c_mean, m200c_err_mean, richness_individual, z_individual, weight_individual):
    
    p = []
    
    logM200c0, alpha, beta = theta
    
    for i, sample in enumerate(m200c_mean):
        
            logm_individual = mu_logM_lambda_f(z_individual[i], np.log10(richness_individual[i]), logM200c0, alpha, beta)
            logm_excpected = np.log10(np.average((10**logm_individual)**Gamma, weights = weight_individual[i], axis = 0)**(1/Gamma))
            
            p.append(gaussian(np.log10(m200c_mean[i]), logm_excpected, m200c_err_mean[i]/(np.log(10)*m200c_mean[i])))
    
    return np.sum(np.log(np.array(p)))

# %%
npath = 100
nwalkers = 100

# %%
import emcee
initial_binned = [14.15,0.,0.75]
pos_binned = initial_binned + 0.01 * np.random.randn(npath, len(initial_binned))
nwalkers, ndim = pos_binned.shape

# %%
m = np.array([s[0] for s in profile_SkySim['M200c']])
profile_SkySim_cut = profile_SkySim[m > 1e14]

# %%
profile_SkySim_cut.colnames
# Out:
# ['cluster_id',
#  'M200c',
#  'cluster_z',
#  'radial_bin',
#  'gt_av',
#  'gx_av',
#  'radius_av',
#  'norm_sum',
#  'halo_id',
#  'dec',
#  'ra',
#  'baseDC2/sod_halo_radius',
#  'halo_mass',
#  'baseDC2/sod_halo_mass',
#  'redshift',
#  'richness',
#  'weight_per_cluster_5',
#  'weight_per_cluster_10']

# %% [markdown]
# Weak lensing mass richness relation

# %%
# %load_ext autoreload

# %autoreload 2
profile_sky_stack = prf.stacked_profile(profile = profile_SkySim_cut,
                    r_in = 'radius_av',
                    gt_in = 'gt_av', gx_in = 'gx_av',
                    r_out = 'radius',
                    gt_out = 'gt', gx_out = 'gx',
                    weight = 'norm_sum',
                    z_name = 'redshift', obs_name = 'richness',
                    Z_bin = Z_bin, Obs_bin = Obs_bin, add_columns_to_bin = ['weight_per_cluster_10','weight_per_cluster_5', 'M200c']
                                       )

covariance_sky_stack = prf.bootstrap_covariance(profile = profile_SkySim_cut,
                    r_in = 'radius_av',
                    gt_in = 'gt_av', gx_in = 'gx_av',
                    r_out = 'radius',
                    gt_out = 'gt', gx_out = 'gx',
                    weight = 'norm_sum',
                    n_boot = 400,
                    z_name = 'redshift', obs_name = 'richness',
                    Z_bin = Z_bin, Obs_bin = Obs_bin)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/make_profile.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   return gt_w/w, gx_w/w, r_w/w
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/make_profile.py:54: RuntimeWarning: invalid value encountered in true_divide
#   return gt_w/w, gx_w/w, r_w/w
# /pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/numpy/ma/core.py:2832: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   order=order, subok=True, ndmin=ndmin)

# %%
for i,p in enumerate(profile_sky_stack):
    plt.errorbar(p['radius'], p['gt'])
plt.loglog()
# Out:
# []

# %%
moo = clmm.Modeling(massdef = 'critical', delta_mdef = 200, halo_profile_model = 'nfw')
moo.set_cosmo(cosmo_clmm)
deff = ccl.halos.massdef.MassDef(200, 'critical', c_m_relation=None)
conc = ccl.halos.concentration.ConcentrationDiemer15(mdef=deff)

# %%
def modele_ds(r, logm, c, cluster_z):

    m = 10.**logm 
    
    moo.set_mass(m), moo.set_concentration(c)
    
    deltasigma = []
        
    for i, xr in enumerate(r):
    
        deltasigma.append(moo.eval_excess_surface_density(xr, cluster_z))
    
    return np.array(deltasigma)

def fitp(profile = 1, covariance = 1, up = 1, down = 1, m_c_relation = 1, fit_2_halo_term = 1):
    
    profile_in = profile
    
    fit_data_name = ['mask',
                     'chi2', 'ddof',
                     'logm200','logm200_err', 
                     'c_w', 'c_w_err',
                     'richness','richness_err', 
                     '1h_term', '2h_term','radius_model', 'z']
    
    tab = {name : [] for name in fit_data_name}
    
    kk = np.logspace(-5,5 ,100000)

    for j, p in enumerate(profile_in):
        
        infos_cov = covariance[j]
        
        cluster_z, R, y_exp, cov_t = p['z_mean'], p['radius'], p['gt'], infos_cov['cov_t']
        
        if fit_2_halo_term == True:

            Pk = twoh.compute_Pk(kk, cluster_z, cosmo_ccl)

            ds_unbaised = twoh.ds_two_halo_term_unbaised(R, cluster_z, cosmo_ccl, kk, Pk)
        
        rmin, rmax = down, up

        mask = (R > rmin)*(R < rmax)
        
        logm = np.logspace(11,16,1000)
        
        c200array = conc._concentration(cosmo_ccl, logm, 1/(1 + cluster_z))
        
        def chi2(logm200, c200):
            
            if m_c_relation == True:

                c200 = np.interp(logm200, logm, c200array)

            bias = twoh.halo_bais(logm = logm200, concentration = c200,
                                         mdef = 'critical', Delta = 200, halo_def = 'nfw',
                                         cluster_z = cluster_z, cosmo_ccl = cosmo_ccl)
            
            if fit_2_halo_term == True:

                y_predict = modele_ds(R, logm200, c200, cluster_z) + bias * ds_unbaised
                
            else : y_predict = modele_ds(R, logm200, c200, cluster_z)
            
            d = (y_predict - y_exp)

            d = np.array([d[i] if mask[i] == True else 0 for i in range(len(mask))])

            inv_cov = np.linalg.inv(np.diag(np.diag(cov_t)))
            
            #inv_cov = np.linalg.inv((cov_t))
            
            m_lnL_ds = np.sum((d[mask]/np.sqrt(cov_t.diagonal()[mask]))**2)

            #m_lnL_ds = 0.5*np.sum(d*inv_cov.dot(d))                                         

            return m_lnL_ds

        minuit = Minuit(chi2, logm200 = 13, c200 = 3, limit_c200 = (0.01,16), fix_c200 = m_c_relation,
                   limit_logm200 = (12,16),
                   errordef = 1)
        

        minuit.migrad(),minuit.hesse(),minuit.minos()
        
        if m_c_relation == True:
            nparams = 1
        else : nparams = 2

        chi2 = minuit.fval
        
        ddof = len(mask[mask == True])-nparams

        logm_fit = minuit.values['logm200']

        logm_fit_err = minuit.errors['logm200']

        c_fit = conc._concentration(cosmo_ccl, 10**logm_fit, 1/(1 + cluster_z))

        c_fit_err = minuit.errors['c200']

        radius, y_exp, y_exp_err = R, y_exp, np.sqrt(cov_t.diagonal())

        ds_1h_term = modele_ds(R,logm_fit,c_fit,cluster_z)

        #hbiais = minuit.values['bias']#twoh.halo_bais(logm = logm_fit, concentration = c_fit,
                                         #mdef = 'critical', Delta = 200, halo_def = 'nfw',
                                         #cluster_z = cluster_z, cosmo_ccl = cosmo_ccl)

        ds_2h_term = 1#hbiais * ds_unbaised

        dat_col = [mask, 
                   chi2, ddof,
                   logm_fit, logm_fit_err, 
                   c_fit, c_fit_err, 
                   p['obs_mean'], p['obs_rms'],
                   ds_1h_term, ds_2h_term, R, p['z_mean']]

    
            #dat_col = [None for i in range(len(fit_data_name))]
            
        for i, name in enumerate(fit_data_name):
            
            tab[name].append(dat_col[i])

    #for name in fit_data_name:
        
       # profile_in[name] = tab[name]
    
    t = Table(tab)
    
    t = hstack([t, profile_in])
        
    return t

# %%
# %time
down = 1
fix_c_2h = fitp(profile = profile_sky_stack, covariance = covariance_sky_stack, up = 10, down = down, m_c_relation = True, fit_2_halo_term = True)
fix_c_1h = fitp(profile = profile_sky_stack, covariance = covariance_sky_stack, up = 5.5, down = down, m_c_relation = True, fit_2_halo_term = False)
free_c_2h = fitp(profile = profile_sky_stack, covariance = covariance_sky_stack,up = 10, down = down, m_c_relation = False, fit_2_halo_term = True)
free_c_1h = fitp(profile = profile_sky_stack, covariance = covariance_sky_stack,up = 5.5, down = down, m_c_relation = False, fit_2_halo_term = False)
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 13.4 µs
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/modeling/two_halo_term.py:72: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   val = quad(integrand  , 2*1e-4 , 20000 , args = ( theta ))[0]
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/modeling/two_halo_term.py:72: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   val = quad(integrand  , 2*1e-4 , 20000 , args = ( theta ))[0]
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/modeling/NFW_profile.py:47: RuntimeWarning: invalid value encountered in log
#   return np.log(1 + c) - c/(1 + c)
# /pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /pbs/throng/lsst/users/cpayerne/GitForThesis/DC2Analysis/modeling/NFW_profile.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   self.r200 = ((self.M200 * 3) / (self.alpha * 800 * np.pi * self.rho_critical)) ** (1./3.)

# %%
fits = [fix_c_2h,fix_c_1h,free_c_2h,free_c_1h]
text = ['c-M, 2h', 'c-M, 1h','free c, 2h','free c, 1h']

# %%
plt.rcParams['axes.linewidth'] = 3
fig, axs = plt.subplots(2, 2, figsize = (20,15), sharex=True, sharey=True)
plt.rcParams['axes.linewidth'] = 3
fig.subplots_adjust(wspace=0, hspace=0)
i_fits = [0,0,1,1]
j_fits = [1,0,1,0]
color_z = ['orange','red','magenta','purple','green','cyan','blue','black']
x = np.linspace(1,3,100)
y = 0.7*x + 13.2
for i,f in enumerate(fits):
    
    
    for k, z_bin in enumerate(Z_bin):
        
            if i == 0:
                
                axs[i_fits[i],j_fits[i]].plot([],[], '-', c = color_z[k],label = f'{z_bin[0]:.2f}'+ r'$< z < $'+ f'{z_bin[1]:.2f}',)
    
            mask = (f['z_mean'] > z_bin[0])*(f['z_mean'] < z_bin[1])

            mask = mask*(f['n_stack'] > 1)

            f_cut = f[mask]

            a_t = 1./(1 + f_cut['z_mean'])

            richness = f_cut['richness']
            richness_err = f_cut['richness_err']
            logm200w = f_cut['logm200']
            logm200w_err = f_cut['logm200_err']
            
            axs[i_fits[i],j_fits[i]].text(1.5, 14.7, text[i], fontsize = 30)

            axs[i_fits[i],j_fits[i]].errorbar(np.log10(richness),logm200w,logm200w_err, richness_err/(np.log(10)*richness),
                    marker = '.', 
                    elinewidth = 2, capsize = 0, markersize = 7, c = color_z[k],fmt = ' ',
                        markerfacecolor = None)
    #axs[i_fits[i],j_fits[i]].set_xlim(1.3,2.4)
    #axs[i_fits[i],j_fits[i]].set_ylim(14,14.8)
    #axs[i_fits[i],j_fits[i]].plot(x,y,'--k')
    axs[i_fits[i],j_fits[i]].tick_params(axis='both', which = 'major', labelsize= 20)
    axs[i_fits[i],j_fits[i]].legend(frameon = False, fontsize = 20, loc = 'lower right')
    axs[i_fits[i],j_fits[i]].grid('True')
    axs[i_fits[i],j_fits[i]].set_xlabel(r'$\log_{10}(\langle \lambda \rangle)$', fontsize = 30)
    if j_fits[i] == 0:
        axs[i_fits[i],j_fits[i]].set_ylabel(r'$\log_{10}(\langle M_{\rm 200c}^{\rm WL}\rangle)$', fontsize = 30)
plt.savefig('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/Images/est_wl_mass.png', bbox_inches='tight', dpi=300)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.rcParams['axes.linewidth'] = 3
fig, axs = plt.subplots(2, 2, figsize = (20,15), sharex=True, sharey=True)
plt.rcParams['axes.linewidth'] = 3
fig.subplots_adjust(wspace=0, hspace=0)
i_fits = [0,0,1,1]
j_fits = [1,0,1,0]
color_z = ['orange','red','magenta','purple','green','cyan','blue','black']
x = np.linspace(1,3,100)
y = np.linspace(14, 14.6, 100)
for i,f in enumerate(fits):
    
    
    for k, z_bin in enumerate(Z_bin):
        
            if i == 0:
                
                axs[i_fits[i],j_fits[i]].plot([],[], '-', c = color_z[k],label = f'{z_bin[0]:.2f}'+ r'$< z < $'+ f'{z_bin[1]:.2f}',)
    
            mask = (f['z_mean'] > z_bin[0])*(f['z_mean'] < z_bin[1])

            mask = mask*(f['n_stack'] > 1)

            f_cut = f[mask]

            logm200 = [np.log10(np.mean(m)) for m in f_cut['M200c']]
            #logm200 = np.log10(np.average(f_cut['M200c'], axis = 1))

            logm200w = f_cut['logm200']
            logm200w_err = f_cut['logm200_err']
            
            #axs[i_fits[i],j_fits[i]].text(14.1, 14.6, text[i], fontsize = 30)

            axs[i_fits[i],j_fits[i]].errorbar(logm200,logm200w,logm200w_err,
                    marker = '.', 
                    elinewidth = 2, capsize = 0, markersize = 7, c = color_z[k], fmt = ' ',
                        markerfacecolor = None)
    #axs[i_fits[i],j_fits[i]].set_xlim(14,14.8)
    #axs[i_fits[i],j_fits[i]].set_ylim(14,14.8)
    axs[i_fits[i],j_fits[i]].plot(y,y,'--k')
    axs[i_fits[i],j_fits[i]].tick_params(axis='both', which = 'major', labelsize= 20)
    axs[i_fits[i],j_fits[i]].legend(frameon = False, fontsize = 20, loc = 'lower right')
    axs[i_fits[i],j_fits[i]].grid('True')
    axs[i_fits[i],j_fits[i]].set_xlabel(r'$\log_{10}(\langle M_{\rm 200c}\rangle)$', fontsize = 30)
    if j_fits[i] == 0:
        axs[i_fits[i],j_fits[i]].set_ylabel(r'$\log_{10}(\langle M_{\rm 200c}^{\rm WL}\rangle)$', fontsize = 30)
plt.savefig('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/Images/est_wl_mass_mass.png', bbox_inches='tight', dpi=300)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
from scipy.stats import chi2

# %%
plt.rcParams['axes.linewidth'] = 3
fig, axs = plt.subplots(2, 2, figsize = (15,10), sharex=True, sharey=True)
plt.rcParams['axes.linewidth'] = 3
fig.subplots_adjust(wspace=0, hspace=0)
i_fits = [0,0,1,1]
j_fits = [1,0,1,0]
color_z = ['orange','red','magenta','purple','green','cyan','blue','black']
x = np.linspace(1,3,100)
y = 0.7*x + 13.2
for i,f in enumerate(fits):
    
    f_cut = f
    chi2ndof = f_cut['chi2']
    ddof = f_cut['ddof']
    x = np.linspace(0,40,1000)
    
    print(ddof[0])

    axs[i_fits[i],j_fits[i]].text(25, 0.08, text[i], fontsize = 20)
    y = chi2.pdf(x,ddof[0])
    bins = np.linspace(0,max(x),12)
    axs[i_fits[i],j_fits[i]].hist(chi2ndof, bins = bins, density= True, alpha = 0.5)
    axs[i_fits[i],j_fits[i]].plot(x,y, '-k', linewidth = 3)
    axs[i_fits[i],j_fits[i]].tick_params(axis='both', which = 'major', labelsize= 20)
    axs[i_fits[i],j_fits[i]].legend(frameon = False, fontsize = 16, loc = 'upper right')
    axs[i_fits[i],j_fits[i]].set_xlabel(r'$\chi^2$', fontsize = 25)
     
plt.savefig('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/Images/chi2_distribution.png', bbox_inches='tight', dpi=300)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 18
# 13
# 17
# 12

# %%
from scipy.stats import norm
def lnL_binned_2(theta, m200c_mean, m200c_err_mean, richness_individual, z_individual, weight_individual, Gamma):
    
    p = []
    
    logM200c0, alpha, beta = theta
    
    for i, sample in enumerate(m200c_mean):
        
            logm_individual = mu_logM_lambda_f(z_individual[i], np.log10(richness_individual[i]), logM200c0, alpha, beta)
            
            logm_excpected = np.log10(np.average((10**logm_individual)**Gamma, weights = weight_individual[i], axis = 0)**(1/Gamma))
            
            p.append(norm.pdf(np.log10(m200c_mean[i]), logm_excpected, m200c_err_mean[i]/(np.log(10)*m200c_mean[i])))
    
    return np.sum(np.log(np.array(p)))

# %%
nwalkers, ndim = pos_binned.shape
label = ['fix_c_2h','fix_c_1h','free_c_2h','free_c_1h']
Gamma_5 = 0.79
Gamma_10 = 0.75
Gamma = [Gamma_10, Gamma_5, Gamma_10, Gamma_5]

_5_or_10 = ['10', '5', '10', '5']
sampler = {name : 0 for name in label}
for i,fit_true in enumerate(fits):
    
    m200c_mean = 10**np.array(fit_true['logm200'])
    m200c_err_mean =np.array(fit_true['logm200_err'])*np.log(10)*m200c_mean
    richness_individual = np.array(fit_true['obs_individual'])
    richness_mean = np.array([np.mean(richness_individual[i]) for i in range(len(richness_individual))])
    z_individual = fit_true['z_individual']
    z_mean = np.array([np.mean(z_individual[i]) for i in range(len(z_individual))])
    weight_individual = fit_true['weight_per_cluster' + '_' + _5_or_10[i]]
    sampler_binned = emcee.EnsembleSampler(nwalkers, ndim, lnL_binned_2, args = (m200c_mean, m200c_err_mean, richness_individual, z_individual, weight_individual, Gamma[i]))
    sampler_binned.run_mcmc(pos_binned, npath, progress=True);
    sampler_binned_wl = sampler_binned.get_chain(discard = 0, flat = True)
    sampler[label[i]] = sampler_binned_wl
# Out:
#  29%|██▉       | 29/100 [02:08<05:20,  4.51s/it]Traceback (most recent call last):
#   File "/pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/ensemble.py", line 545, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "<ipython-input-424-1415a00e8d11>", line 10, in lnL_binned_2
#     logm_individual = mu_logM_lambda_f(z_individual[i], np.log10(richness_individual[i]), logM200c0, alpha, beta)
#   File "<ipython-input-407-3055ce20111a>", line 5, in mu_logM_lambda_f
#     return logM200c0 + alpha*np.log10((1+redshift)/(1 + z0)) + beta*(logrichness-np.log10(richness0))
#   File "/pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py", line 399, in __array_finalize__
#     self.parent_table = None
#   File "/pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py", line 888, in __setattr__
#     super().__setattr__(item, value)
#   File "/pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py", line 289, in parent_table
#     self._parent_table = None
#   File "/pbs/home/c/cpayerne/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py", line 885, in __setattr__
#     def __setattr__(self, item, value):
# KeyboardInterrupt
#  29%|██▉       | 29/100 [02:09<05:16,  4.46s/it]
# emcee: Exception while calling your likelihood function:
#   params: [14.07817331 -0.5698875   0.64100691]

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-425-790776765bd4> in <module>
#      17     weight_individual = fit_true['weight_per_cluster' + '_' + _5_or_10[i]]
#      18     sampler_binned = emcee.EnsembleSampler(nwalkers, ndim, lnL_binned_2, args = (m200c_mean, m200c_err_mean, richness_individual, z_individual, weight_individual, Gamma[i]))
# ---> 19     sampler_binned.run_mcmc(pos_binned, npath, progress=True);
#      20     sampler_binned_wl = sampler_binned.get_chain(discard = 0, flat = True)
#      21     sampler[label[i]] = sampler_binned_wl
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     382
#     383         results = None
# --> 384         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     385             pass
#     386
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     341
#     342                     # Propose
# --> 343                     state, accepted = move.propose(model, state)
#     344                     state.random_state = self.random_state
#     345
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/moves/red_blue.py in propose(self, model, state)
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     425                 map_func = map
#     426             results = list(
# --> 427                 map_func(self.log_prob_fn, (p[i] for i in range(len(p))))
#     428             )
#     429
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/emcee/ensemble.py in __call__(self, x)
#     543     def __call__(self, x):
#     544         try:
# --> 545             return self.f(x, *self.args, **self.kwargs)
#     546         except:  # pragma: no cover
#     547             import traceback
#
# <ipython-input-424-1415a00e8d11> in lnL_binned_2(theta, m200c_mean, m200c_err_mean, richness_individual, z_individual, weight_individual, Gamma)
#       8     for i, sample in enumerate(m200c_mean):
#       9
# ---> 10             logm_individual = mu_logM_lambda_f(z_individual[i], np.log10(richness_individual[i]), logM200c0, alpha, beta)
#      11
#      12             logm_excpected = np.log10(np.average((10**logm_individual)**Gamma, weights = weight_individual[i], axis = 0)**(1/Gamma))
#
# <ipython-input-407-3055ce20111a> in mu_logM_lambda_f(redshift, logrichness, logM200c0, alpha, beta)
#       3
#       4 def mu_logM_lambda_f(redshift, logrichness, logM200c0, alpha, beta):
# ----> 5     return logM200c0 + alpha*np.log10((1+redshift)/(1 + z0)) + beta*(logrichness-np.log10(richness0))
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py in __array_finalize__(self, obj)
#     397         # or viewcast e.g. obj.view(Column).  In either case we want to
#     398         # init Column attributes for self from obj if possible.
# --> 399         self.parent_table = None
#     400         if not hasattr(self, 'indices'):  # may have been copied in __new__
#     401             self.indices = []
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py in __setattr__(self, item, value)
#     886         if not isinstance(self, MaskedColumn) and item == "mask":
#     887             raise AttributeError("cannot set mask value to a column in non-masked Table")
# --> 888         super().__setattr__(item, value)
#     889
#     890         if item == 'unit' and issubclass(self.dtype.type, np.number):
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py in parent_table(self, table)
#     287     def parent_table(self, table):
#     288         if table is None:
# --> 289             self._parent_table = None
#     290         else:
#     291             self._parent_table = weakref.ref(table)
#
# ~/.conda/envs/mydesc/lib/python3.7/site-packages/astropy/table/column.py in __setattr__(self, item, value)
#     883         return self
#     884
# --> 885     def __setattr__(self, item, value):
#     886         if not isinstance(self, MaskedColumn) and item == "mask":
#     887             raise AttributeError("cannot set mask value to a column in non-masked Table")
#
# KeyboardInterrupt:

# %%
plt.plot(sampler['fix_c_1h'][:,1])

# %%
labels = [r'$\log_{10}(M_{\rm 200c,0})$', r'$G_\mu^z$',r'$F_\lambda^\mu$']
def mu_sigma(samples = 1, labels = 1, sig = 1):
    t = {labels[i] : np.mean(samples[:,i]) for i in range(len(labels))}
    mu = []
    sigma = []
    range_ = []
    for i in range(len(labels)):
        mu_i = np.mean(samples[:,i])
        sigma_i = np.std(samples[:,i])
        mu.append(mu_i)
        sigma.append(sigma_i)
        range_.append([mu_i-sig*sigma_i, mu_i+sig*sigma_i])
    return mu, sigma, range_, t
mu, sigma, range_, t_binned_wl = mu_sigma(samples = flat_samples_binned_true, labels = labels, sig = 4)

# %%
range_

# %%
label_plot = [ r'c-M, 2h',r'c-M, 1h',r'free c, 2h',r'free c, 1h','validation',]

# %%
sampler_tot = [ sampler['fix_c_2h'], sampler['fix_c_1h'],sampler['free_c_2h'],sampler['free_c_1h'],flat_samples_binned_true]

# %%
plt.rcParams['axes.linewidth'] = 2
sigma1 = 1. - np.exp(-(1./1.)**2/2.)
sigma2 = 1. - np.exp(-(2./1.)**2/2.)
sigma3 = 1. - np.exp(-(3./1.)**2/2.)
truth = [14.162, -0.23, 0.8]
bins = 20
range_ = [(14.1, 14.22), (-0.62, 0.3), (0.65, 0.82)]
c = ['blue','k','red','orange','cyan']
fill_contours = [False, False, False,False,  True]
fig, axs = plt.subplots(len(labels), len(labels), figsize = (10,10))
for i, name in enumerate(label_plot):
    axs[0,2].plot([],[], c[i], linewidth = 10, label = label_plot[i])

for i,sample in enumerate(sampler_tot):
    a = len(sample)
    print(a)
    sample_cut = sample[6000:a-1]
    fig = corner.corner(
    sample_cut,
    bins=bins, levels=(sigma1, sigma2),
    range = range_,
    fig = fig,
    color = c[i],
    truths = truth,
    smooth1d=True,smooth=True,plot_datapoints=False,
    fill_contours=fill_contours[i], labels = labels,            
    label_kwargs={"fontsize": 20},
    use_math_text=True,
    show_title = True,
    plot_density=False,
    max_n_ticks = 5);
    
for i in range(len(labels)):
    for j in range(len(labels)):
        axs[i,j].tick_params(axis='both', which = 'major', labelsize= 15)
        axs[i,j].legend(frameon = False, fontsize = 25)
        if i == j:
            axs[i,j].set_ylim(0,1000)

plt.savefig('/pbs/throng/lsst/users/cpayerne/ThesisAtCCin2p3/Images/MCMC_mass_Richness.png', bbox_inches='tight', dpi=300)

# %%
a = len(flat_samples_binned_true)
for i,label in enumerate(labels):
    mu = np.mean(flat_samples_binned_true[6000:a-1][:,i])
    std = np.std(flat_samples_binned_true[6000:a-1][:,i])
    print(label)
    print(mu)
    print(std)
